# %%
import pandas as pd

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
import seaborn as sns
import pandas as pd

sns.heatmap(data.pivot_table(index='y', columns='x', values='z'), 
                             cbar_kws={'label': 'colorbar title'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-98d5ba8d31d1> in <module>
#       2 import pandas as pd
#       3
# ----> 4 sns.heatmap(data.pivot_table(index='y', columns='x', values='z'),
#       5                              cbar_kws={'label': 'colorbar title'})
#
# NameError: name 'data' is not defined

# %%
plt.show()

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 10, 6

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# sphinx_gallery_thumbnail_number = 2


for exp in [173, 176]:
    harvest = pd.read_csv("/home/doodle/pedro/doodle-kaggle/code/logs/class_probs/exp_{}.csv".format(exp)).transpose()
    vegetables = list(range(len(harvest)))
    farmers =  list(range(len(harvest.iloc[0])))

    fig, ax = plt.subplots()
    im = ax.imshow(harvest)

    sns.heatmap(harvest, cbar=True, xticklabels=False, yticklabels=False )
    # Rotate the tick labels and set their alignment.

    # cbar.ax.set_ylabel("Prob", rotation=-90, va="bottom")
    plt.xlabel("Time", fontsize=20)
    plt.ylabel("Category", fontsize=20)
    fig.tight_layout()
    plt.show()
