# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd 
# sphinx_gallery_thumbnail_number = 2
import seaborn as sns

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 20, 5

# %%
for exp in [352, 353, 354]:
    harvest = pd.read_csv("/home/doodle/pedro/doodle-kaggle/code/logs/class_probs/exp_{}.csv".format(exp)).transpose()
    vegetables = list(range(len(harvest)))
    farmers =  list(range(len(harvest.iloc[0])))

    fig, ax = plt.subplots(figsize=(20,5))
    im = ax.imshow(harvest)
    ax.set_aspect(3)
    sns.heatmap(harvest, cbar=True, xticklabels=5, yticklabels=list(range(1, 11)), square=False)
    # Rotate the tick labels and set their alignment.

    # cbar.ax.set_ylabel("Prob", rotation=-90, va="bottom")
    plt.xlabel("Epoch", fontsize=15)
    plt.ylabel("Cluster", fontsize=15)
    fig.tight_layout()
    plt.show()
